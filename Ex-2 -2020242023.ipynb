# %% [markdown]
# 1.
# (a) The sample size n is extremely large, and the number of predic-
# tors p is small.
#     Flexible methods are better.When the sample size n is very large and p is small, flexible methods can capitalize on the large amount of data to fit more complex models without overfitting.
#
# (b) The number of predictors p is extremely large, and the number
# of observations n is small.
#     Inflexible methods are better.When p is large relative to n, flexible methods are more prone to overfitting because they have many parameters to estimate but only a small amount of data to do so.
#
# (c) The relationship between the predictors and response is highly
# non-linear.
#     Flexible methods are better.Flexible methods, such as non-parametric models, splines, or kernel methods, are better equipped to capture highly non-linear relationships between predictors and response.
#
# (d) The variance of the error terms, i.e. σ 2 = Var("), is extremely
# high.
#     Inflexible methods works better.High variance in the error terms means that the noise in the data is very large. Flexible methods, which fit the data more closely, are more susceptible to this noise.
#
#
# 2.
# (a)
#       Regression: This is a typical regression problem because CEO salary is a numerical value, and we are interested in modeling its dependence on other numerical or categorical variables.
#
#       Inference: This involves interpreting the coefficients and understanding which factors significantly affect CEO salary.
#
#       n (Number of Observations): The number of firms 500
#       p (Number of Predictors): 3 (profit, number of employees, industry; CEO salary is the outcome variable)
#
#   (b)
#       Classification: The outcome variable (success or failure) is categorical, so this is a classification problem. We are interested in predicting whether the new product will be successful or not.
#
#       Prediction: predict the success or failure of the new product based on the given variables. The focus is on accurately predicting the outcome
#
#       n (Number of Observations): The number of products 20
#       p (Number of Predictors): 11 (price, marketing budget, competition price, and ten other variables; success/failure is the outcome variable)
#
#   (c)
#       Regression: The goal is to predict a continuous outcome based on other continuous predictors. This fits the regression model since both the outcome and predictors are numerical.
#
#       Prediction: The main objective is to forecast the % change in the USD/Euro exchange rate based on the weekly stock market changes. We are focused on generating accurate predictions.
#
#       n (Number of Observations): 52(assuming 52 weeks in a year)
#       p (Number of Predictors): 3 (% change in the US market, % change in the British market, % change in the German market; % change in USD/Euro is the outcome variable)
#
#   3.
#   (a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range of flexibility (e.g., from 1 to 10)
flexibility = np.linspace(1, 10, 500)

# Define the error curves
# Bias^2 decreases as flexibility increases
bias_squared = 1 / flexibility**2
# Variance increases as flexibility increases
variance = flexibility / 10
# Training error decreases with flexibility
training_error = 1 / flexibility
# Test error is the sum of bias^2, variance, and irreducible error
# Assume irreducible error (Bayes error) is a constant
irreducible_error = 0.1
test_error = bias_squared + variance + irreducible_error

# Plot the curves
plt.figure(figsize=(10, 6))

plt.plot(flexibility, bias_squared, label='Squared Bias', color='blue')
plt.plot(flexibility, variance, label='Variance', color='red')
plt.plot(flexibility, training_error, label='Training Error', color='green')
plt.plot(flexibility, test_error, label='Test Error', color='purple')
plt.axhline(y=irreducible_error, color='orange', linestyle='--', label='Irreducible Error')

plt.xlabel('Flexibility')
plt.ylabel('Error')
plt.title('Bias-Variance Decomposition')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# (b)
# Squared Bias:
# Shape: Decreases as flexibility increases.
# Reason: With more flexibility, the model can better fit the training data, reducing the bias.
#
# Variance:
# Shape: Increases with flexibility.
# Reason: As the model becomes more flexible, it can fit the training data more closely, which can lead to high variance.
#
# Training Error:
# Shape: Decreases with flexibility.
# Reason: A more flexible model can fit the training data more closely, thus reducing the training error.
#
# Test Error:
# Shape: Typically U-shaped.
# Reason: Initially, as flexibility increases, the test error decreases because the model's fit improves.
#
# Irreducible Error (Bayes Error):
# Shape: Constant.
# Reason: This is the minimum achievable error due to noise in the data and is independent of the model's flexibility.
#
# 4.
# (a) Real-Life Applications of Classification
#
# Medical Diagnosis
# Response: Whether a patient has a particular disease (e.g., cancer) or not.
# Predictors: Age, gender, blood pressure, cholesterol levels, genetic markers, lifestyle factors.
# Goal: Prediction. The goal is to accurately predict whether a patient has the disease based on the predictors.
#
# Email Spam Detection
# Response: Whether an email is spam or not.
# Predictors: Keywords in the email, frequency of certain words, sender information, email length, presence of attachments.
# Goal: Prediction. The goal is to automatically categorize incoming emails as spam or not, helping users manage their inboxes more efficiently.
#
# Credit Card Fraud Detection
# Response: Whether a credit card transaction is fraudulent or not.
# Predictors: Transaction amount, location, time of transaction, user’s purchasing history, device used for the transaction.
# Goal: Prediction. The goal is to identify potentially fraudulent transactions in real-time to prevent financial loss.
#
# (b) Real-Life Applications of Regression
#
# House Price Prediction
# Response: Price of a house.
# Predictors: Square footage, number of bedrooms, location, age of the house, proximity to schools and parks.
# Goal: Prediction. The goal is to predict the price of a house based on its characteristics, helping buyers and sellers make informed decisions.
#
# Sales Forecasting
# Response: Monthly sales revenue.
# Predictors: Advertising expenditure, seasonal factors, economic indicators, competitor pricing, historical sales data.
# Goal: Prediction. The goal is to predict future sales revenue, which can help businesses in planning inventory, staffing, and marketing strategies.
#
# Predicting Patient Recovery Time
# Response: Number of days a patient takes to recover from surgery.
# Predictors: Patient’s age, type of surgery, pre-existing conditions, lifestyle factors, post-surgery care.
# Goal: Inference. The goal might be to understand how different factors influence recovery time, which can help in personalizing patient care.
#
# (c) Real-Life Applications of Cluster Analysis
#
# Customer Segmentation
# Application: Segmenting customers into groups based on purchasing behavior for targeted marketing.
# Goal: To identify distinct customer groups that exhibit similar purchasing behaviors so that marketing strategies can be tailored to each group.
#
# Market Research
# Application: Grouping survey respondents based on their responses to understand different market segments.
# Goal: To uncover patterns in consumer preferences and behaviors, helping businesses tailor their products and services to different market segments.
#
# Image Segmentation
# Application: Dividing an image into different segments to identify objects, boundaries, or regions.
# Goal: To automatically process images for tasks like object recognition, where different regions of an image need to be identified and processed separately.
#
# 5.
# Very Flexible Approach
#
# Advantages:
#   Better Fit to Training Data
#   Ability to Model Non-Linear Relationships:
#   Customization
#
# Disadvantages:
#    Overfitting
#    Increased Variance
#    Complexity
#
# Less Flexible Approach
#
# Advantages:
#    Lower Risk of Overfitting
#    Simplicity and Interpretability
#    Efficiency
#
# Disadvantages:
#    Poor Fit to Complex Data
#    Limited in Modeling Non-Linear Relationships
#
# Prefer a More Flexible Approach
#    Complex Data
#    Large Datasets
#    When Prediction Accuracy is Critical
#
# Prefer a Less Flexible Approach
#    Small Datasets
#    Need for Interpretability
#    Computational Constraints
#
# 6.
# Differences Between Parametric and Non-Parametric Approaches
#
# Parametric Statistical Learning Approach:
# Assumption of Functional Form:
#    Parametric methods assume a specific functional form or distribution for the model (e.g., linear regression assumes a linear relationship between the predictors and the response).
# Modeling Process:
#   Selecting a model: Choosing a specific form for the function (e.g., linear, quadratic).
#   Estimating parameters: Using the training data to estimate the parameters of the model (e.g., the coefficients in a linear regression).
# Examples:
#   Linear regression, logistic regression, and linear discriminant analysis
#
# Non-Parametric Statistical Learning Approach:
# No Assumption of Functional Form:
#   Non-parametric methods do not assume any specific form for the relationship between the predictors and the response, allowing for more flexibility.
# Modeling Process:
#   These methods attempt to fit the model structure more directly from the data without assuming a predefined form. The complexity of the model often increases with the size of the dataset.
# Examples:
#   K-nearest neighbors(KNN), decision trees, and kernel density estimation.
#
# Parametric Approach:
# Advantages
#   Simplicity and Interpretability
#   Less Data Requirement
#   Computational Efficiency
#   Easier Inference
# Disadvantages
#   Model Bias
#   Limited Flexibility
#
# Non-Parametric Approach:
# Advantages
#   Flexibility
#   Less Model Bias
# Disadvantages
#   Data Requirement
#   Computational Complexity
#   Interpretability
#
# 7.
# (a) Compute the Euclidean Distance
# Distance from Observation 1 (0, 3, 0):3
# Distance from Observation 2 (2, 0, 0):2
# Distance from Observation 3 (0, 1, 3):3.16
# Distance from Observation 4 (0, 1, 2):2.24
# Distance from Observation 5 (1, 0, 1):1.41
# Distance from Observation 6 (1, 1, 1):1.73
#
# (b) Prediction with k=1
# with K=1, we consider the closest observation to the test point.
# The closest observation is Observation 5 with a distance of
# 2≈1.41 The response Y for Observation 5 is Green.
# Prediction with K=1: Green
#
# (c) Prediction with k=3
# with K=3, we consider the three closest observations to the test point.
# The three closest observations are:
# Observation 5 (Green) with a distance of 2≈1.41
# Observation 6 (Red) with a distance of 3≈1.73
# Observation 2 (Red) with a distance of 2
# Among these, 2 are Red and 1 is Green.
# Prediction with K=3: Red (since the majority of the closest neighbors are Red)
#
# (d) Best Value for K with a Non-Linear Bayes Decision Boundary
# If the Bayes decision boundary is highly non-linear, we would expect the best value for K to be small.
#
# Reasoning:
#   A small K allows the model to be more flexible and responsive to local variations in the data, which is important when the decision boundary is complex and non-linear.
#
#   A large K would average over a broader set of observations, potentially smoothing out and missing important local patterns, leading to higher bias and less accurate predictions in regions where the decision boundary is highly non-linear.
